# %%
import obspy
import seisbench
import seisbench.models as sbm
import pandas as pd
import pickle

from __future__ import print_function
import numpy as np
import h5py
import glob
import math
import os
import shutil
from scipy import signal
from scipy.signal import butter, lfilter
from keras.layers import Input, Dense, Conv2D, MaxPooling2D, UpSampling2D, Conv1D, MaxPooling1D, UpSampling1D, Flatten, Dropout, Reshape, GaussianNoise 
from keras.layers import Bidirectional, BatchNormalization, ZeroPadding1D, Conv2DTranspose
from keras.models import Model, Sequential
from keras import backend as K
from tensorflow.keras.optimizers import SGD, Adam
from keras import regularizers
from tensorflow.keras.layers import Layer, InputSpec
from keras.callbacks import ModelCheckpoint, LearningRateScheduler, ReduceLROnPlateau, EarlyStopping
from keras.initializers import VarianceScaling
from keras.callbacks import CSVLogger
from scipy.optimize import linear_sum_assignment as linear_assignment
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
import metrics
import matplotlib.pyplot as plt
from matplotlib.pyplot import savefig
# Out:
# 2022-04-03 17:01:21.211518: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-04-03 17:01:21.211565: I tensorflow/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.

# %%
time = np.arange(0, 86.4, 0.00001);
sine = np.sin(time)
noise = np.random.normal(0,0.1,8640000)
noisy_sine = sine + noise

zeros = [0] * 8640000
sine_noise_by_time = [[noisy_sine[i], zeros[i], zeros[i]] for i in range(len(noisy_sine))]

stream = [noisy_sine, zeros, zeros]

step_size = 1000 # originally 16, try to increase to 1000 to represent 10 seconds
batched_stream_arr_by_time = [sine_noise_by_time[i:i + step_size] for i in range(0, len(sine_noise_by_time), step_size)]

# %%
# step_size = 10000
inp = Input(shape=(step_size,3,1))  

e = GaussianNoise(0.2)(inp)

e = Conv2D(8, (3, 3), activation='selu', padding='same')(e)
e = MaxPooling2D((10, 3), padding='same')(e)
e = Conv2D(4, (3, 3), activation='selu', padding='same')(e)
e = MaxPooling2D((10, 1), padding='same')(e)
e = Conv2D(2, (3, 3), activation='selu', padding='same')(e)
e = MaxPooling2D((5, 1), padding='same')(e)

shape_before_flattening = K.int_shape(e)
encoded = Flatten()(e)
d = Reshape(shape_before_flattening[1:])(encoded)

d = Conv2D(2, (3, 3), activation='selu', padding='same')(d)
d = UpSampling2D((5, 1))(d)
d = Conv2D(4, (3, 3), activation='selu', padding='same')(d)
d = UpSampling2D((10, 1))(d)
d = Conv2D(8, (3, 3), activation='sigmoid', padding='same')(d)
d = UpSampling2D((10, 3))(d)
decoded = Conv2D(1, (3, 3), padding='same')(d)

autoencoder = Model(inputs=inp, outputs=decoded, name='autoencoder')
encoder = Model(inputs=inp, outputs=encoded, name='encoder')

autoencoder.compile(loss="binary_crossentropy", optimizer=SGD(lr=0.5))
csv_logger = CSVLogger('pretrain_log.csv')

autoencoder.summary()
# Out:
# Model: "autoencoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 30000, 3, 1)]     0
#
#  gaussian_noise_2 (GaussianN  (None, 30000, 3, 1)      0
#  oise)
#
#  conv2d_22 (Conv2D)          (None, 30000, 3, 8)       80
#
#  max_pooling2d_9 (MaxPooling  (None, 3000, 1, 8)       0
#  2D)
#
#  conv2d_23 (Conv2D)          (None, 3000, 1, 4)        292
#
#  max_pooling2d_10 (MaxPoolin  (None, 300, 1, 4)        0
#  g2D)
#
#  conv2d_24 (Conv2D)          (None, 300, 1, 2)         74
#
#  max_pooling2d_11 (MaxPoolin  (None, 60, 1, 2)         0
#  g2D)
#
#  flatten_3 (Flatten)         (None, 120)               0
#
#  reshape_4 (Reshape)         (None, 60, 1, 2)          0
#
#  conv2d_25 (Conv2D)          (None, 60, 1, 2)          38
#
#  up_sampling2d_9 (UpSampling  (None, 300, 1, 2)        0
#  2D)
#
#  conv2d_26 (Conv2D)          (None, 300, 1, 4)         76
#
#  up_sampling2d_10 (UpSamplin  (None, 3000, 1, 4)       0
#  g2D)
#
#  conv2d_27 (Conv2D)          (None, 3000, 1, 8)        296
#
#  up_sampling2d_11 (UpSamplin  (None, 30000, 3, 8)      0
#  g2D)
#
#  conv2d_28 (Conv2D)          (None, 30000, 3, 1)       73
#
# =================================================================
# Total params: 929
# Trainable params: 929
# Non-trainable params: 0
# _________________________________________________________________
# /global/home/users/albertwen/.local/lib/python3.9/site-packages/keras/optimizer_v2/gradient_descent.py:102: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(SGD, self).__init__(name, **kwargs)

# %%
autoencoder.fit(batched_stream_arr_by_time, batched_stream_arr_by_time, batch_size=128, epochs=30, callbacks=[csv_logger])
# Out:
# Epoch 1/30
# 3/3 [==============================] - 5s 1s/step - loss: 1.0593
# Epoch 2/30
# 3/3 [==============================] - 4s 1s/step - loss: 0.0590
# Epoch 3/30
# 3/3 [==============================] - 4s 1s/step - loss: 0.0590
# Epoch 4/30
# 3/3 [==============================] - 4s 1s/step - loss: 0.0590
# Epoch 5/30
# 3/3 [==============================] - 4s 1s/step - loss: 0.0590
# Epoch 6/30
# 3/3 [==============================] - 4s 1s/step - loss: 0.0590
# Epoch 7/30
# 3/3 [==============================] - 4s 1s/step - loss: 0.0590
# Epoch 8/30
# 3/3 [==============================] - 4s 1s/step - loss: 0.0590
# Epoch 9/30
# 3/3 [==============================] - 4s 1s/step - loss: 0.0590
# Epoch 10/30
# 3/3 [==============================] - 4s 1s/step - loss: 0.0590
# Epoch 11/30
# 3/3 [==============================] - 4s 1s/step - loss: 0.0590
# Epoch 12/30
# 3/3 [==============================] - 4s 1s/step - loss: 0.0590
# Epoch 13/30
# 3/3 [==============================] - 4s 1s/step - loss: 0.0590
# Epoch 14/30
# 3/3 [==============================] - 4s 1s/step - loss: 0.0590
# Epoch 15/30
# 3/3 [==============================] - 4s 1s/step - loss: 0.0590
# Epoch 16/30

# %%
class ClusteringLayer(Layer):
    def __init__(self, n_clusters, weights=None, alpha=1.0, **kwargs):
        if 'input_shape' not in kwargs and 'input_dim' in kwargs:
            kwargs['input_shape'] = (kwargs.pop('input_dim'),)
        super(ClusteringLayer, self).__init__(**kwargs)
        self.n_clusters = n_clusters
        self.alpha = alpha
        self.initial_weights = weights
        self.input_spec = InputSpec(ndim=2)

    def build(self, input_shape):
        assert len(input_shape) == 2
        input_dim = input_shape[1]
        self.input_spec = InputSpec(dtype=K.floatx(), shape=(None, input_dim))
        self.clusters = self.add_weight(shape=(self.n_clusters, input_dim), initializer='glorot_uniform', name='clusters')
        if self.initial_weights is not None:
            self.set_weights(self.initial_weights)
            del self.initial_weights
        self.built = True

    def call(self, inputs, **kwargs):
        q = 1.0 / (1.0 + (K.sum(K.square(K.expand_dims(inputs, axis=1) - self.clusters), axis=2) / self.alpha))
        q **= (self.alpha + 1.0) / 2.0
        q = K.transpose(K.transpose(q) / K.sum(q, axis=1)) 
        return q

    def compute_output_shape(self, input_shape):
        assert input_shape and len(input_shape) == 2
        return input_shape[0], self.n_clusters

    def get_config(self):
        config = {'n_clusters': self.n_clusters}
        base_config = super(ClusteringLayer, self).get_config()
        return dict(list(base_config.items()) + list(config.items()))
    
print('...Finetuning...')
n_clusters = 2
clustering_layer = ClusteringLayer(n_clusters, name='clustering')(encoder.output)
model = Model(inputs=[encoder.input], outputs=[clustering_layer, encoder.output])
model.compile(loss=['kld', 'mse'], loss_weights=[0.1, 1], optimizer='adam')

# from keras.utils import plot_model
# plot_model(model, to_file='model.png', show_shapes=True)
# from IPython.display import Image
# Image(filename='model.png')
# Out:
# ...Finetuning...

# %%
kmeans = KMeans(n_clusters=n_clusters, n_init=20)
y_pred = kmeans.fit_predict(encoder.predict(batched_stream_arr_by_time))
y_pred_last = np.copy(y_pred)
model.get_layer(name='clustering').set_weights([kmeans.cluster_centers_])

# %%
def plot_waves(stream, predictions):
    fig = plt.figure(figsize=(16, 10))
    clusters = list(set(predictions))
    axs = fig.subplots(len(clusters)+1, 1, sharex=True, sharey=True, gridspec_kw={'hspace': 0})
                
    df = pd.DataFrame({'E': stream[0], 'N': stream[1], 'Z': stream[2]})
    step_size = 30000
    df['y_pred'] = np.repeat(y_pred, step_size)
    
    for i in range(3):
        axs[0].plot(df.index, df.iloc[:, i], label = df.columns[i])
    
    for i in clusters:
        cluster = df[df['y_pred'] == i]
        for j in range(3):
            axs[i + 1].plot(cluster.index, cluster.iloc[:, j], label=df.columns[j])
        
        axs[i+1].legend()
        axs[i+1].title.set_text("Cluster " + str(i))
        
    axs[0].legend()
    axs[0].title.set_text("Stream")

    plt.show()
    return 0

# %%
plot_waves(stream, y_pred)
# Out:
# 0
